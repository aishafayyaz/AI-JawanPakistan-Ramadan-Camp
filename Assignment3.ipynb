# %%
# Simple Calculator Program

print("Simple Calculator")
print("Choose operation:")
print("1. Addition (+)")
print("2. Subtraction (-)")
print("3. Multiplication (*)")
print("4. Division (/)")
print("5. Power (^)")

choice = input("Enter choice (1/2/3/4/5): ")

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if choice == '1':
    print("Result:", num1 + num2)

elif choice == '2':
    print("Result:", num1 - num2)

elif choice == '3':
    print("Result:", num1 * num2)

elif choice == '4':
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Error! Division by zero is not allowed.")

elif choice == '5':
    print("Result:", num1 ** num2)

else:
    print("Invalid input! Please choose a correct operation.")
# Out:
# Simple Calculator
# Choose operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Power (^)
# Enter choice (1/2/3/4/5):  5
# Enter first number:  5
# Enter second number:  3
# Result: 125.0

# %%
# Write a python program to check if there is any numeric value in list using for loop

my_list = ["ali", "orange", 10, "parrot", 3.5]

found = False   

for item in my_list:
    if isinstance(item, (int, float)):  
        found = True
        break  

if found:
    print("The list contains at least one numeric value.")
else:
    print("The list does NOT contain any numeric value.")
# Out:
# The list contains at least one numeric value.

# %%
# Write a python program to add a key to a dictionary

profile = {"name":"Ahmed", "age":25,"city":"Karachi"}
add_key="education"
key_value="Bachelors"
profile[add_key]=key_value
print("Updated profile is :", profile)
# Out:
# Updated profile is : {'name': 'Ahmed', 'age': 25, 'city': 'Karachi', 'education': 'Bachelors'}

# %%
# Write a python program to sum all the numeric items in a dictionary

my_dict = {"a": 10, "b": 5, "c": "hello", "d": 1.5,"e":"greetings","f":3}
total = 0
for value in my_dict.values():
    if isinstance(value, (int, float)):
        total += value

print("Sum of all numeric values:", total)
# Out:
# Sum of all numeric values: 19.5

# %%
# Write a python program to find duplicate values in a list

my_list = [1, 2, 3, 2, 4, 5, 1, 4, 0, 6, 11, 2]
seen = set()
duplicates = set()
for item in my_list:
    if item in seen:
        duplicates.add(item)
    else:
        seen.add(item)

print("Duplicate values in the list:",list(duplicates))
# Out:
# Duplicate values in the list: [1, 2, 4]

# %%
# Write a python program to check if a key already exists in a dictionary

profile = {"name":"Ahmed", "age":25,"city":"Karachi"}
print(profile)
key_to_check = input("Enter the key to check :")
if key_to_check in profile:
    print("The key '{key_to_check}' exists in the dictionary.")
else:
    print("The key '{key_to_check}' does NOT exist in the dictionary.")
# Out:
# {'name': 'Ahmed', 'age': 25, 'city': 'Karachi'}
# Enter the key to check : city
# The key '{key_to_check}' exists in the dictionary.
