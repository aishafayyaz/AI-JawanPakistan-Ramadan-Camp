# %%
from platform import python_version
print(python_version())
# Out:
# 3.13.1

# %%
from datetime import datetime
current_datetime = datetime.now()
print("Current date and time:", current_datetime)
# Out:
# Current date and time: 2026-02-26 23:18:50.688000

# %%
radius = float(input("Enter radius of the circle:"))
area = (22/7) * radius * radius
print("Area of the circle is:", area)
# Out:
# Enter radius of the circle: 6
# Area of the circle is: 113.14285714285714

# %%
first_name = input("Enter first name:")
second_name = input("Enter second name:")
reverse_first_name = "".join(reversed(first_name))
reverse_second_name = "".join(reversed(second_name))
print(reverse_first_name,"",reverse_second_name)
# Out:
# Enter first name: aisha
# Enter second name: farooq
# ahsia  qooraf

# %%
input1= int(input("Enter first number:"))
input2=int(input("Enter second number:"))
print("The sum of two numbers is: ", input1+input2)
# Out:
# Enter first number: 6
# Enter second number: 5
# The sum of two numbers is:  11

# %%
number = int(input("Enter number:"))
if (number%2==0):
    print(number,"is an even number")
else:
    print(number,"is an odd number")
# Out:
# Enter number: 8
# 8 is an even number
